# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DS14.csv',index_col=0)
df.head()
# Out:
#       cohort_biomass_mt
# year
# 0                 138.0
# 1                 246.0
# 2                 528.0
# 3                 940.0
# 4                 913.0
