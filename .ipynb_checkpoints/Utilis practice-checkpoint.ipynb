# %%
# %%writefile utils.py

import utils
import importlib
importlib.reload(utils)
# Out:
# <module 'utils' from 'C:\\Users\\ereno\\Math 440\\utils.py'>

# %%
utils.my_function()
# Out:
# Hello from utils.py!

# %%
utils.say_hello('Eren')
# Out:
# 'Hello, Eren!'

# %%
utils.hello_world()
# Out:
# hello world
